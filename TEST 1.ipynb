# %%
import pandas as pd
df=pd.read_csv("C:/Users/Scarlett RED/Desktop/project.csv", encoding='cp1252')
data=df.iloc[7:,]
data.head()
# Out:
#                             Unnamed: 0                   Unnamed: 1  \
# 7                              Disease  Count of Disease Occurrence
# 8   UMLS:C0020538_hypertensive disease                         3363
# 9                                  NaN                          NaN
# 10                                 NaN                          NaN
# 11                                 NaN                          NaN
#
#                            Unnamed: 2
# 7                             Symptom
# 8            UMLS:C0008031_pain chest
# 9   UMLS:C0392680_shortness of breath
# 10            UMLS:C0012833_dizziness
# 11             UMLS:C0004093_asthenia

# %%
new_header = data.iloc[0] #grab the first row for the header
data = data[1:] #take the data less the header row
data.columns = new_header #set the header row as the data header

# %%
new_header
# Out:
# Unnamed: 0                        Disease
# Unnamed: 1    Count of Disease Occurrence
# Unnamed: 2                        Symptom
# Name: 7, dtype: object

# %%
data.columns
# Out:
# Index(['Disease', 'Count of Disease Occurrence', 'Symptom'], dtype='object', name=7)

# %%
data.head()
# Out:
# 7                              Disease Count of Disease Occurrence  \
# 8   UMLS:C0020538_hypertensive disease                        3363
# 9                                  NaN                         NaN
# 10                                 NaN                         NaN
# 11                                 NaN                         NaN
# 12                                 NaN                         NaN
#
# 7                             Symptom
# 8            UMLS:C0008031_pain chest
# 9   UMLS:C0392680_shortness of breath
# 10            UMLS:C0012833_dizziness
# 11             UMLS:C0004093_asthenia
# 12                 UMLS:C0085639_fall

# %%
fill=data.fillna(method='ffill')

# %%
fill.head()
# Out:
# 7                              Disease Count of Disease Occurrence  \
# 8   UMLS:C0020538_hypertensive disease                        3363
# 9   UMLS:C0020538_hypertensive disease                        3363
# 10  UMLS:C0020538_hypertensive disease                        3363
# 11  UMLS:C0020538_hypertensive disease                        3363
# 12  UMLS:C0020538_hypertensive disease                        3363
#
# 7                             Symptom
# 8            UMLS:C0008031_pain chest
# 9   UMLS:C0392680_shortness of breath
# 10            UMLS:C0012833_dizziness
# 11             UMLS:C0004093_asthenia
# 12                 UMLS:C0085639_fall

# %%
sort=fill.sort_values('Symptom')
sort
# Out:
# 7                                               Disease  \
# 1815                                UMLS:C1258215_ileus
# 946                        UMLS:C0546817_overload fluid
# 990                            UMLS:C0004610_bacteremia
# 501                           UMLS:C0019196_hepatitis C
# 681                             UMLS:C0003864_arthritis
# 721                          UMLS:C0029456_osteoporosis
# 618                             UMLS:C1623038_cirrhosis
# 1346                             UMLS:C0017601_glaucoma
# 947                          UMLS:C0030920_ulcer peptic
# 1748                        UMLS:C0008325_cholecystitis
# 616                             UMLS:C1623038_cirrhosis
# 1383                UMLS:C0011880_ketoacidosis diabetic
# 1370  UMLS:C0007102_malignant tumor of colon^UMLS:C0...
# 972                             UMLS:C0017152_gastritis
# 1421                  UMLS:C0006826_malignant neoplasms
# 1450                      UMLS:C0017160_gastroenteritis
# ...

# %%
s=data['Symptom']

# %%
import numpy as np
a=np.array(s)
u=np.unique(a,return_counts=True)
u
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-793048280823> in <module>
#       1 import numpy as np
#       2 a=np.array(s)
# ----> 3 u=np.unique(a,return_counts=True)
#       4 u
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     262     ar = np.asanyarray(ar)
#     263     if axis is None:
# --> 264         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     265         return _unpack_tuple(ret)
#     266
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     310         aux = ar[perm]
#     311     else:
# --> 312         ar.sort()
#     313         aux = ar
#     314     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
x
# Out:
# array(['UMLS:C0008031_pain chest', 'UMLS:C0392680_shortness of breath',
#        'UMLS:C0012833_dizziness', ..., 'UMLS:C0871754_frail',
#        'UMLS:C0015967_fever', nan], dtype=object)

# %%
a=set(s)
b=list(a)

# %%
b.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-2127d0239a6c> in <module>
# ----> 1 b.count()
#
# TypeError: count() takes exactly one argument (0 given)

# %%
fill.set_index('Symptom')
# Out:
# 7                                                                                             Disease  \
# Symptom
# UMLS:C0008031_pain chest                                           UMLS:C0020538_hypertensive disease
# UMLS:C0392680_shortness of breath                                  UMLS:C0020538_hypertensive disease
# UMLS:C0012833_dizziness                                            UMLS:C0020538_hypertensive disease
# UMLS:C0004093_asthenia                                             UMLS:C0020538_hypertensive disease
# UMLS:C0085639_fall                                                 UMLS:C0020538_hypertensive disease
# UMLS:C0039070_syncope                                              UMLS:C0020538_hypertensive disease
# UMLS:C0042571_vertigo                                              UMLS:C0020538_hypertensive disease
# UMLS:C0038990_sweat^UMLS:C0700590_sweating incr...                 UMLS:C0020538_hypertensive disease
# ...

# %%
fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 8 to 1874
# Data columns (total 3 columns):
# Disease                        1867 non-null object
# Count of Disease Occurrence    1867 non-null object
# Symptom                        1867 non-null object
# dtypes: object(3)
# memory usage: 43.8+ KB

# %%
choice=input("Enter symptoms:" )
print(choice)
# Out:
# Enter symptoms:fever
# fever

# %%
req=fill[fill['Symptom'].str.contains(choice)]
req
# Out:
# 7                                               Disease  \
# 65                              UMLS:C0032285_pneumonia
# 139                             UMLS:C0021311_infection
# 151               UMLS:C0042029_infection urinary tract
# 193                              UMLS:C0497327_dementia
# 313   UMLS:C0001175_acquired immuno-deficiency syndr...
# 331                            UMLS:C0007642_cellulitis
# 358   UMLS:C0036690_septicemia^UMLS:C0243026_systemi...
# 384                           UMLS:C0011175_dehydration
# 473                UMLS:C0022661_chronic kidney failure
# 624                             UMLS:C0015230_exanthema
# 686                            UMLS:C0006277_bronchitis
# 874                    UMLS:C0024228_lymphatic diseases
# 929                        UMLS:C0012813_diverticulitis
# 962                         UMLS:C0029443_osteomyelitis
# 983                            UMLS:C0004610_bacteremia
# 1039          UMLS:C0041912_upper respiratory infection
# ...

# %%
req.info()
s=req['Count of Disease Occurrence']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 65 to 1874
# Data columns (total 3 columns):
# Disease                        37 non-null object
# Count of Disease Occurrence    37 non-null object
# Symptom                        37 non-null object
# dtypes: object(3)
# memory usage: 1.2+ KB

# %%
x=req['Count of Disease Occurrence'].sum()
y=np.array(x)
y/37
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-abd62f9c83f0> in <module>
#       1 x=req['Count of Disease Occurrence'].sum()
#       2 y=np.array(x)
# ----> 3 y/37
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
